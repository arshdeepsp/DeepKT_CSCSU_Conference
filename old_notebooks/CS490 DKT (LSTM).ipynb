# %% [markdown]
# # CS490 Deep Knowledge Tracing using LSTM
#
# ---
#
# Implementation in TensorFlow. Trained using Assistments 2017

# %% [markdown]
# # Importing Required Modules
# ---

# %%
from tensorflow.keras import layers
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, LayerNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.metrics import AUC
from tensorflow.keras.regularizers import L2

from sklearn.model_selection import train_test_split

import numpy as np
import pandas as pd

# %% [markdown]
# Also importing dataset

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/MyDrive/DeepKT/assistments_2017.csv')

data.head(20)
# Out:
# <ipython-input-4-22e1cf0703e2>:1: DtypeWarning: Columns (76,77) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('/content/drive/MyDrive/Colab/assistments_2017.csv')
#     studentId  MiddleSchoolId InferredGender SY ASSISTments Usage   AveKnow  \
# 0           8               2           Male            2004-2005  0.352416
# 1           8               2           Male            2004-2005  0.352416
# 2           8               2           Male            2004-2005  0.352416
# 3           8               2           Male            2004-2005  0.352416
# 4           8               2           Male            2004-2005  0.352416
# 5           8               2           Male            2004-2005  0.352416
# 6           8               2           Male            2004-2005  0.352416
# 7           8               2           Male            2004-2005  0.352416
# 8           8               2           Male            2004-2005  0.352416
# 9           8               2           Male            2004-2005  0.352416
# 10          8               2           Male            2004-2005  0.352416
# 11          8               2           Male            2004-2005  0.352416
# 12          8               2           Male            2004-2005  0.352416
# 13          8               2           Male            2004-2005  0.352416
# 14          8               2           Male            2004-2005  0.352416
# 15          8               2           Male            2004-2005  0.352416
# 16          8               2           Male            2004-2005  0.352416
# 17          8               2           Male            2004-2005  0.352416
# 18          8               2           Male            2004-2005  0.352416
# 19          8               2           Male            2004-2005  0.352416
#
#     AveCarelessness  AveCorrect  NumActions  AveResBored  AveResEngcon  ...  \
# 0          0.183276    0.483902        1056     0.208389      0.679126  ...
# 1          0.183276    0.483902        1056     0.208389      0.679126  ...
# 2          0.183276    0.483902        1056     0.208389      0.679126  ...
# 3          0.183276    0.483902        1056     0.208389      0.679126  ...
# 4          0.183276    0.483902        1056     0.208389      0.679126  ...
# 5          0.183276    0.483902        1056     0.208389      0.679126  ...
# 6          0.183276    0.483902        1056     0.208389      0.679126  ...
# 7          0.183276    0.483902        1056     0.208389      0.679126  ...
# 8          0.183276    0.483902        1056     0.208389      0.679126  ...
# 9          0.183276    0.483902        1056     0.208389      0.679126  ...
# 10         0.183276    0.483902        1056     0.208389      0.679126  ...
# 11         0.183276    0.483902        1056     0.208389      0.679126  ...
# 12         0.183276    0.483902        1056     0.208389      0.679126  ...
# 13         0.183276    0.483902        1056     0.208389      0.679126  ...
# 14         0.183276    0.483902        1056     0.208389      0.679126  ...
# 15         0.183276    0.483902        1056     0.208389      0.679126  ...
# 16         0.183276    0.483902        1056     0.208389      0.679126  ...
# 17         0.183276    0.483902        1056     0.208389      0.679126  ...
# 18         0.183276    0.483902        1056     0.208389      0.679126  ...
# 19         0.183276    0.483902        1056     0.208389      0.679126  ...
#
#     RES_CONFUSED  RES_FRUSTRATED  RES_OFFTASK  RES_GAMING      Ln-1        Ln  \
# 0       0.000000        0.000000     0.785585    0.000264      0.13   0.06119
# 1       0.887452        0.000000     0.468252    0.001483   0.06119   0.21351
# 2       0.887452        0.000000     0.468252    0.001483     0.116  0.033306
# 3       0.000000        0.000000     0.108417    0.010665     0.116  0.033306
# 4       0.000000        0.000000     0.108417    0.010665  0.033306  0.118386
# 5       0.000000        0.000000     0.785585    0.002026  0.033306  0.118386
# 6       0.000000        1.000000     0.108417    0.005952  0.033306  0.118386
# 7       0.060808        0.000000     0.785585    0.010665     0.348  0.138588
# 8       0.060808        0.000000     0.916914    0.012562     0.168  0.097911
# 9       0.060808        0.000000     0.916914    0.012562     0.168  0.097911
# 10      0.000000        0.009561     0.088541    0.006837     0.168  0.097911
# 11      0.000000        0.009561     0.468252    0.002815  0.097911  0.301679
# 12      0.633474        0.000000     0.785585    0.002815  0.138588  0.093798
# 13      0.000000        0.009561     0.108417    0.006837  0.138588  0.093798
# 14      0.633474        0.000000     0.785585    0.001483  0.093798  0.086489
# 15      0.000000        0.009561     0.108417    0.004243  0.093798  0.086489
# 16      0.000000        0.009561     0.149121    0.005797     0.212  0.482958
# 17      0.060808        0.000000     0.118054    0.005797     0.031  0.022011
# 18      0.000000        0.000000     0.108417    0.004324  0.022011  0.020825
# 19      0.000000        0.000000     0.108417    0.004324  0.022011  0.020825
#
#     MCAS Enrolled  Selective  isSTEM
# 0     45        0          0     NaN
# 1     45        0          0     NaN
# 2     45        0          0     NaN
# 3     45        0          0     NaN
# 4     45        0          0     NaN
# 5     45        0          0     NaN
# 6     45        0          0     NaN
# 7     45        0          0     NaN
# 8     45        0          0     NaN
# 9     45        0          0     NaN
# 10    45        0          0     NaN
# 11    45        0          0     NaN
# 12    45        0          0     NaN
# 13    45        0          0     NaN
# 14    45        0          0     NaN
# 15    45        0          0     NaN
# 16    45        0          0     NaN
# 17    45        0          0     NaN
# 18    45        0          0     NaN
# 19    45        0          0     NaN
#
# [20 rows x 82 columns]

# %% [markdown]
# # Defining Model
# ---

# %%
class LSTM_DKTModel(Model):
    def __init__(self, num_skills, embed_dim=64, lstm_units=128, num_lstm_layers=2, dropout_rate=0.1):
        super(LSTM_DKTModel, self).__init__()

        # Input dimension is 2 * num_skills to account for correct/incorrect per skill
        self.input_dim = 2 * num_skills
        self.num_skills = num_skills
        self.lstm_units = lstm_units

        # Embedding layer for skill-correctness pairs
        self.embedding = Embedding(self.input_dim, embed_dim)

        # Stack of LSTM layers
        self.lstm_layers = []
        for i in range(num_lstm_layers):
            # Return sequences True for all layers to maintain sequence length
            self.lstm_layers.append(
                LSTM(
                    units=lstm_units,
                    return_sequences=True,
                    dropout=dropout_rate,
                    recurrent_dropout=dropout_rate/2,  # Lower dropout for recurrent connections
                    name=f'lstm_layer_{i}'
                )
            )

        # Layer normalization after LSTM for stable training
        self.layer_norm = LayerNormalization(epsilon=1e-6)

        # Dropout for regularization
        self.dropout = Dropout(dropout_rate)

        # Output layer predicts probability for each skill
        self.fc = Dense(num_skills, activation="sigmoid")

    def call(self, inputs, training=False):
        # Get input shape
        input_shape = tf.shape(inputs)
        batch_size = input_shape[0]
        seq_len = input_shape[1]

        # Embedding layer
        x = self.embedding(inputs)  # Shape: (batch_size, seq_len, embed_dim)

        # Process through LSTM layers
        for lstm_layer in self.lstm_layers:
            x = lstm_layer(x, training=training)

        # Apply layer normalization
        x = self.layer_norm(x)

        # Apply dropout
        x = self.dropout(x, training=training)

        # Output layer
        return self.fc(x)  # Shape: (batch_size, seq_len, num_skills)

# %% [markdown]
# # Preprocess
# ---

# %%
def create_skill_mappings(df):
    skills = df['skill'].unique()
    skill_to_id = {skill: idx for idx, skill in enumerate(skills)}
    id_to_skill = {idx: skill for skill, idx in skill_to_id.items()}
    return skill_to_id, id_to_skill

def create_interaction_index(row, skill_to_id):
    skill_id = skill_to_id[row['skill']]
    return 2 * skill_id + row['correct']

def prepare_sequences(df, skill_to_id, sequence_length=50):
    num_skills = len(skill_to_id)
    sequences = []
    next_skill_masks = []

    df = df.sort_values('startTime')

    for i in range(0, len(df) - sequence_length):
        window = df.iloc[i:i + sequence_length]
        sequence = []
        next_masks = []

        for j in range(len(window) - 1):
            current_interaction = create_interaction_index(window.iloc[j], skill_to_id)
            sequence.append(current_interaction)

            next_skill = window.iloc[j + 1]['skill']
            skill_mask = np.zeros(num_skills)
            skill_mask[skill_to_id[next_skill]] = 1
            next_masks.append(skill_mask)

        sequences.append(sequence)
        next_skill_masks.append(next_masks)

    return np.array(sequences), np.array(next_skill_masks)

def create_data_splits(df, skill_to_id, sequence_length=50, test_size=0.2, val_size=0.1):
    # Prepare sequences
    X, Y = prepare_sequences(df, skill_to_id, sequence_length)

    # First split: separate test set
    X_temp, X_test, Y_temp, Y_test = train_test_split(
        X, Y, test_size=test_size, shuffle=False
    )

    # Second split: separate validation from training
    val_size_adjusted = val_size / (1 - test_size)
    X_train, X_val, Y_train, Y_val = train_test_split(
        X_temp, Y_temp, test_size=val_size_adjusted, shuffle=False
    )

    # Convert to TensorFlow tensors
    data_splits = {
        'X_train': tf.convert_to_tensor(X_train, dtype=tf.int32),
        'Y_train': tf.convert_to_tensor(Y_train, dtype=tf.int32),
        'X_val': tf.convert_to_tensor(X_val, dtype=tf.int32),
        'Y_val': tf.convert_to_tensor(Y_val, dtype=tf.int32),
        'X_test': tf.convert_to_tensor(X_test, dtype=tf.int32),
        'Y_test': tf.convert_to_tensor(Y_test, dtype=tf.int32)
    }

    return data_splits


class DKTDataGenerator(tf.keras.utils.Sequence):
    def __init__(self, interaction_indices, next_skill_masks, batch_size=32):
        self.interaction_indices = interaction_indices
        self.next_skill_masks = next_skill_masks
        self.batch_size = batch_size
        self.indices = np.arange(len(self.interaction_indices))

    def __len__(self):
        return int(np.ceil(len(self.indices) / self.batch_size))

    def __getitem__(self, idx):
        start_idx = idx * self.batch_size
        end_idx = min((idx + 1) * self.batch_size, len(self.indices))
        batch_indices = self.indices[start_idx:end_idx]

        # Ensure inputs are properly shaped (batch_size, sequence_length)
        batch_x = np.array([self.interaction_indices[i] for i in batch_indices])
        batch_y = np.array([self.next_skill_masks[i] for i in batch_indices])

        return tf.convert_to_tensor(batch_x), tf.convert_to_tensor(batch_y)

    def on_epoch_end(self):
        np.random.shuffle(self.indices)

df = data[data['studentId'] == 8]  # Your student data

# Create skill mappings
skill_to_id, id_to_skill = create_skill_mappings(df)

# Create all data splits
data_splits = create_data_splits(
    df=df,
    skill_to_id=skill_to_id,
    sequence_length=50,
    test_size=0.2,
    val_size=0.1
)

# %% [markdown]
# # Training Code
# ---

# %%
def train_model(train_generator, val_generator, num_skills, epochs=50):
    model = LSTM_DKTModel(
        num_skills=num_skills,
        embed_dim=64,
        lstm_units=128,
        num_lstm_layers=2,
        dropout_rate=0.2
    )

    optimizer = tf.keras.optimizers.AdamW(
        learning_rate=0.001,
        weight_decay=0.01,
        clipnorm=1.0
    )

    model.compile(
        optimizer=optimizer,
        loss=tf.keras.losses.BinaryCrossentropy(),
        metrics=['accuracy', tf.keras.metrics.AUC(name='auc')]
    )

    callbacks = [
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=7,
            restore_best_weights=True,
            min_delta=0.001
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=5,
            min_lr=0.0001,
            min_delta=0.001
        ),
        tf.keras.callbacks.ModelCheckpoint(
            'dkt_model_best.weights.h5',
            monitor='val_auc',
            save_best_only=True,
            save_weights_only=True,
            mode='max'
        )
    ]

    history = model.fit(
        train_generator,
        validation_data=val_generator,
        epochs=epochs,
        callbacks=callbacks
    )

    return model, history

# Main training execution
def execute_training(data_splits, skill_to_id, batch_size=32, epochs=50):
    train_generator = DKTDataGenerator(
        data_splits['X_train'],
        data_splits['Y_train'],
        batch_size=batch_size
    )

    val_generator = DKTDataGenerator(
        data_splits['X_val'],
        data_splits['Y_val'],
        batch_size=batch_size
    )

    model, history = train_model(
        train_generator,
        val_generator,
        num_skills=len(skill_to_id),
        epochs=epochs
    )

    return model, history

# %% [markdown]
# # Testing Code
# ---

# %%
def evaluate_model(model, data_splits, id_to_skill):
    test_predictions = model.predict(data_splits['X_test'])

    test_results = model.evaluate(
        data_splits['X_test'],
        data_splits['Y_test'],
        verbose=0
    )

    print("\nOverall Test Set Performance:")
    print(f"Loss: {test_results[0]:.4f}")
    print(f"Accuracy: {test_results[1]:.4f}")
    print(f"AUC: {test_results[2]:.4f}")

    return test_predictions

def analyze_skill_performance(predictions, true_values, id_to_skill):
    num_skills = len(id_to_skill)
    skill_metrics = {}

    for skill_id in range(num_skills):
        skill_name = id_to_skill[skill_id]

        # Reshape tensors to 1D arrays
        skill_pred = tf.reshape(predictions[:, :, skill_id], [-1])
        skill_true = tf.reshape(true_values[:, :, skill_id], [-1])

        # Calculate metrics
        accuracy = tf.reduce_mean(tf.keras.metrics.binary_accuracy(skill_true, skill_pred))
        auc = tf.keras.metrics.AUC()
        auc.update_state(skill_true, skill_pred)

        skill_metrics[skill_name] = {
            'accuracy': float(accuracy),
            'auc': float(auc.result())
        }

    return skill_metrics

def analyze_sequential_predictions(predictions, true_values, id_to_skill, num_sequences=5):
    for seq_idx in range(min(num_sequences, predictions.shape[0])):
        print(f"\nSequence {seq_idx + 1} Analysis:")
        sequence_pred = predictions[seq_idx]
        sequence_true = true_values[seq_idx]

        for step in range(sequence_pred.shape[0]):
            pred_skill_id = int(tf.argmax(sequence_pred[step]))
            true_skill_id = int(tf.argmax(sequence_true[step]))

            pred_prob = float(sequence_pred[step][pred_skill_id])

            print(f"\nStep {step + 1}:")
            print(f"Predicted Skill: {id_to_skill[pred_skill_id]}")
            print(f"Actual Skill: {id_to_skill[true_skill_id]}")
            print(f"Prediction Confidence: {pred_prob:.3f}")

def run_model_evaluation(model, data_splits, id_to_skill):
    print("Starting model evaluation...")

    test_predictions = evaluate_model(model, data_splits, id_to_skill)

    skill_metrics = analyze_skill_performance(
        test_predictions,
        data_splits['Y_test'],
        id_to_skill
    )

    print("\nPer-Skill Performance:")
    for skill, metrics in skill_metrics.items():
        print(f"\nSkill: {skill}")
        print(f"Accuracy: {metrics['accuracy']:.4f}")
        print(f"AUC: {metrics['auc']:.4f}")

    print("\nDetailed Sequence Analysis:")
    analyze_sequential_predictions(
        test_predictions,
        data_splits['Y_test'],
        id_to_skill
    )

    return test_predictions, skill_metrics

def execute_testing(model, data_splits, skill_to_id):
    """
    Executes the complete testing pipeline.
    """
    id_to_skill = {v: k for k, v in skill_to_id.items()}
    predictions, metrics = run_model_evaluation(model, data_splits, id_to_skill)
    return predictions, metrics

# %% [markdown]
# # Run
# ---

# %%
# Train the model
model, history = execute_training(
    data_splits=data_splits,
    skill_to_id=skill_to_id,
    batch_size=32,
    epochs=25
)

execute_testing(
    model=model,
    data_splits=data_splits,
    skill_to_id=skill_to_id
)

model.save('lstm_dkt_model.keras')
# Out:
# Epoch 1/25
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 13s 234ms/step - accuracy: 0.0137 - auc: 0.4978 - loss: 0.4716 - val_accuracy: 0.0000e+00 - val_auc: 0.6390 - val_loss: 0.0969 - learning_rate: 0.0010
# Epoch 2/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 11s 255ms/step - accuracy: 0.0294 - auc: 0.5913 - loss: 0.0943 - val_accuracy: 0.0978 - val_auc: 0.7012 - val_loss: 0.0685 - learning_rate: 0.0010
# Epoch 3/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 11s 292ms/step - accuracy: 0.0692 - auc: 0.6760 - loss: 0.0698 - val_accuracy: 0.0707 - val_auc: 0.6241 - val_loss: 0.0684 - learning_rate: 0.0010
# Epoch 4/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 8s 181ms/step - accuracy: 0.1107 - auc: 0.7236 - loss: 0.0654 - val_accuracy: 0.1158 - val_auc: 0.5943 - val_loss: 0.0686 - learning_rate: 0.0010
# Epoch 5/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 6s 237ms/step - accuracy: 0.1593 - auc: 0.7503 - loss: 0.0628 - val_accuracy: 0.1568 - val_auc: 0.5932 - val_loss: 0.0673 - learning_rate: 0.0010
# Epoch 6/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 6s 245ms/step - accuracy: 0.2418 - auc: 0.7939 - loss: 0.0586 - val_accuracy: 0.1772 - val_auc: 0.6342 - val_loss: 0.0668 - learning_rate: 0.0010
# Epoch 7/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 184ms/step - accuracy: 0.3259 - auc: 0.8385 - loss: 0.0540 - val_accuracy: 0.2524 - val_auc: 0.6808 - val_loss: 0.0660 - learning_rate: 0.0010
# Epoch 8/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 229ms/step - accuracy: 0.4002 - auc: 0.8754 - loss: 0.0497 - val_accuracy: 0.2788 - val_auc: 0.7113 - val_loss: 0.0708 - learning_rate: 0.0010
# Epoch 9/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 184ms/step - accuracy: 0.4527 - auc: 0.9036 - loss: 0.0458 - val_accuracy: 0.2869 - val_auc: 0.7308 - val_loss: 0.0720 - learning_rate: 0.0010
# Epoch 10/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 6s 261ms/step - accuracy: 0.4854 - auc: 0.9220 - loss: 0.0427 - val_accuracy: 0.2912 - val_auc: 0.7398 - val_loss: 0.0686 - learning_rate: 0.0010
# Epoch 11/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 8s 333ms/step - accuracy: 0.5234 - auc: 0.9361 - loss: 0.0402 - val_accuracy: 0.2976 - val_auc: 0.7502 - val_loss: 0.0650 - learning_rate: 0.0010
# Epoch 12/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 12s 415ms/step - accuracy: 0.5422 - auc: 0.9461 - loss: 0.0382 - val_accuracy: 0.2991 - val_auc: 0.7624 - val_loss: 0.0593 - learning_rate: 0.0010
# Epoch 13/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 273ms/step - accuracy: 0.5773 - auc: 0.9560 - loss: 0.0358 - val_accuracy: 0.3051 - val_auc: 0.7712 - val_loss: 0.0586 - learning_rate: 0.0010
# Epoch 14/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 231ms/step - accuracy: 0.5882 - auc: 0.9603 - loss: 0.0342 - val_accuracy: 0.3003 - val_auc: 0.7824 - val_loss: 0.0584 - learning_rate: 0.0010
# Epoch 15/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 9s 182ms/step - accuracy: 0.6184 - auc: 0.9692 - loss: 0.0318 - val_accuracy: 0.3059 - val_auc: 0.7849 - val_loss: 0.0590 - learning_rate: 0.0010
# Epoch 16/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 8s 301ms/step - accuracy: 0.6394 - auc: 0.9735 - loss: 0.0303 - val_accuracy: 0.3053 - val_auc: 0.7968 - val_loss: 0.0574 - learning_rate: 0.0010
# Epoch 17/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 182ms/step - accuracy: 0.6350 - auc: 0.9748 - loss: 0.0296 - val_accuracy: 0.3067 - val_auc: 0.8016 - val_loss: 0.0575 - learning_rate: 0.0010
# Epoch 18/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 5s 188ms/step - accuracy: 0.6539 - auc: 0.9777 - loss: 0.0285 - val_accuracy: 0.3053 - val_auc: 0.8090 - val_loss: 0.0585 - learning_rate: 0.0010
# Epoch 19/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 8s 308ms/step - accuracy: 0.6769 - auc: 0.9801 - loss: 0.0267 - val_accuracy: 0.3104 - val_auc: 0.8147 - val_loss: 0.0584 - learning_rate: 0.0010
# Epoch 20/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 188ms/step - accuracy: 0.6757 - auc: 0.9816 - loss: 0.0264 - val_accuracy: 0.3104 - val_auc: 0.8065 - val_loss: 0.0585 - learning_rate: 0.0010
# Epoch 21/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 8s 320ms/step - accuracy: 0.6858 - auc: 0.9827 - loss: 0.0256 - val_accuracy: 0.3182 - val_auc: 0.8015 - val_loss: 0.0604 - learning_rate: 0.0010
# Epoch 22/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 186ms/step - accuracy: 0.6945 - auc: 0.9844 - loss: 0.0248 - val_accuracy: 0.3259 - val_auc: 0.8132 - val_loss: 0.0590 - learning_rate: 5.0000e-04
# Epoch 23/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 185ms/step - accuracy: 0.7096 - auc: 0.9857 - loss: 0.0238 - val_accuracy: 0.3243 - val_auc: 0.8069 - val_loss: 0.0602 - learning_rate: 5.0000e-04
# Starting model evaluation...
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step
#
# Overall Test Set Performance:
# Loss: 0.0735
# Accuracy: 0.1514
# AUC: 0.6900
#
# Per-Skill Performance:
#
# Skill: properties-of-geometric-figures
# Accuracy: 0.9851
# AUC: 0.5184
#
# Skill: sum-of-interior-angles-more-than-3-sides
# Accuracy: 0.9604
# AUC: 0.7039
#
# Skill: point-plotting
# Accuracy: 0.9822
# AUC: 0.4660
#
# Skill: transformations-rotations
# Accuracy: 1.0000
# AUC: 0.0000
#
# Skill: reading-graph
# Accuracy: 0.9321
# AUC: 0.8332
#
# Skill: area
# Accuracy: 0.9482
# AUC: 0.7015
#
# Skill: perimeter
# Accuracy: 0.9855
# AUC: 0.4080
#
# Skill: square-root
# Accuracy: 1.0000
# AUC: 0.0000
#
# Skill: isosceles-triangle
# Accuracy: 0.9802
# AUC: 0.4816
#
# Skill: application: isosceles triangle
# Accuracy: 1.0000
# AUC: 0.0000
#
# Skill: multiplying-decimals
# Accuracy: 0.9752
# AUC: 0.3548
#
# Skill: proportion
# Accuracy: 0.9999
# AUC: 0.9996
#
# Skill: pythagorean-theorem
# Accuracy: 1.0000
# AUC: 0.0000
#
# Skill: interpreting-linear-equations
# Accuracy: 0.9994
# AUC: 0.0000
#
# Skill: pattern-finding
# Accuracy: 0.9807
# AUC: 0.4010
#
# Skill: application: compare points
# Accuracy: 0.9999
# AUC: 0.0000
#
# Skill: application: multi-column subtraction
# Accuracy: 0.9999
# AUC: 0.0000
#
# Skill: application: simple multiplication
# Accuracy: 1.0000
# AUC: 0.0000
#
# Skill: application: compare expressions
# Accuracy: 1.0000
# AUC: 0.0000
#
# Skill: application: order of operations
# Accuracy: 1.0000
# AUC: 0.0000
#
# Skill: application: multi-column addition
# Accuracy: 1.0000
# AUC: 0.0000
#
# Skill: noskill
# Accuracy: 1.0000
# AUC: 0.0000
#
# Skill: application: read points
# Accuracy: 1.0000
# AUC: 0.0000
#
# Skill: application: find slope in graph
# Accuracy: 1.0000
# AUC: 0.0000
#
# Skill: p-patterns-relations-algebra
# Accuracy: 0.9950
# AUC: 0.4582
#
# Skill: percent-of
# Accuracy: 0.9504
# AUC: 0.7790
#
# Skill: venn-diagram
# Accuracy: 0.9810
# AUC: 0.9935
#
# Skill: equivalent-fractions-decimals-percents
# Accuracy: 0.9950
# AUC: 0.6579
#
# Skill: of-means-multiply
# Accuracy: 1.0000
# AUC: 0.0000
#
# Skill: fraction-multiplication
# Accuracy: 1.0000
# AUC: 0.0000
#
# Skill: supplementary-angles
# Accuracy: 0.9762
# AUC: 0.7757
#
# Skill: transversals
# Accuracy: 0.9901
# AUC: 0.9853
#
# Skill: triangle-inequality
# Accuracy: 0.9959
# AUC: 0.2785
#
# Skill: multiplication
# Accuracy: 0.9570
# AUC: 0.8341
#
# Skill: equation-solving
# Accuracy: 0.9621
# AUC: 0.6589
#
# Skill: discount
# Accuracy: 0.9501
# AUC: 0.8120
#
# Skill: sum-of-interior-angles-triangle
# Accuracy: 1.0000
# AUC: 0.0000
#
# Skill: inducing-functions
# Accuracy: 1.0000
# AUC: 0.0000
#
# Skill: subtraction
# Accuracy: 1.0000
# AUC: 0.0000
#
# Skill: addition
# Accuracy: 0.9106
# AUC: 0.0000
#
# Skill: division
# Accuracy: 1.0000
# AUC: 0.0000
#
# Skill: divide-decimals
# Accuracy: 1.0000
# AUC: 0.0000
#
# Skill: making-sense-of-expressions-and-equations
# Accuracy: 0.9961
# AUC: 0.9989
#
# Skill: ordering-numbers
# Accuracy: 0.9986
# AUC: 0.3551
#
# Skill: fraction-division
# Accuracy: 1.0000
# AUC: 0.0000
#
# Skill: evaluating-functions
# Accuracy: 0.9699
# AUC: 0.9201
#
# Skill: substitution
# Accuracy: 0.9689
# AUC: 0.0000
#
# Skill: algebraic-manipulation
# Accuracy: 1.0000
# AUC: 0.0000
#
# Skill: number-line
# Accuracy: 1.0000
# AUC: 0.0000
#
# Skill: exponents
# Accuracy: 1.0000
# AUC: 0.0000
#
# Skill: comparing-fractions
# Accuracy: 1.0000
# AUC: 0.0000
#
# Skill: scientific-notation
# Accuracy: 0.9950
# AUC: 0.3856
#
# Skill: order-of-operations
# Accuracy: 0.9691
# AUC: 0.3539
#
# Skill: reciprocal
# Accuracy: 0.9705
# AUC: 0.7734
#
# Skill: finding-percents
# Accuracy: 1.0000
# AUC: 0.0000
#
# Skill: subtracting-decimals
# Accuracy: 0.9604
# AUC: 0.5798
#
# Skill: integers
# Accuracy: 1.0000
# AUC: 0.0000
#
# Skill: n-number-sense-operations
# Accuracy: 0.9851
# AUC: 0.5957
#
# Skill: probability
# Accuracy: 0.9188
# AUC: 0.8362
#
# Skill: combinatorics
# Accuracy: 1.0000
# AUC: 0.0000
#
# Skill: symbolization-articulation
# Accuracy: 0.9983
# AUC: 0.0000
#
# Skill: mean
# Accuracy: 0.8682
# AUC: 0.8787
#
# Skill: meaning-of-pi
# Accuracy: 1.0000
# AUC: 0.0000
#
# Skill: interpreting-numberline
# Accuracy: 0.9950
# AUC: 0.8338
#
# Skill: graph-shape
# Accuracy: 0.9208
# AUC: 0.6516
#
# Skill: linear-area-volume-conversion
# Accuracy: 0.9631
# AUC: 0.3175
#
# Skill: inequality-solving
# Accuracy: 1.0000
# AUC: 0.0000
#
# Skill: fractions
# Accuracy: 1.0000
# AUC: 0.0000
#
# Skill: percents
# Accuracy: 0.9653
# AUC: 0.3579
#
# Skill: unit-conversion
# Accuracy: 0.9917
# AUC: 0.9775
#
# Skill: equation-concept
# Accuracy: 0.9950
# AUC: 0.4074
#
# Skill: rate
# Accuracy: 1.0000
# AUC: 0.0000
#
# Skill: median
# Accuracy: 0.9620
# AUC: 0.4998
#
# Skill: mode
# Accuracy: 0.9968
# AUC: 0.4681
#
# Skill: statistics
# Accuracy: 0.9752
# AUC: 0.6382
#
# Skill: circle-graph
# Accuracy: 0.9901
# AUC: 0.6811
#
# Detailed Sequence Analysis:
#
# Sequence 1 Analysis:
#
# Step 1:
# Predicted Skill: application: compare points
# Actual Skill: proportion
# Prediction Confidence: 0.387
#
# Step 2:
# Predicted Skill: application: multi-column subtraction
# Actual Skill: multiplication
# Prediction Confidence: 0.552
#
# Step 3:
# Predicted Skill: application: multi-column subtraction
# Actual Skill: multiplication
# Prediction Confidence: 0.284
#
# Step 4:
# Predicted Skill: multiplication
# Actual Skill: multiplication
# Prediction Confidence: 0.114
#
# Step 5:
# Predicted Skill: multiplication
# Actual Skill: median
# Prediction Confidence: 0.194
#
# Step 6:
# Predicted Skill: multiplication
# Actual Skill: mean
# Prediction Confidence: 0.152
#
# Step 7:
# Predicted Skill: multiplication
# Actual Skill: mean
# Prediction Confidence: 0.058
#
# Step 8:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.046
#
# Step 9:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.118
#
# Step 10:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.252
#
# Step 11:
# Predicted Skill: addition
# Actual Skill: median
# Prediction Confidence: 0.356
#
# Step 12:
# Predicted Skill: addition
# Actual Skill: median
# Prediction Confidence: 0.293
#
# Step 13:
# Predicted Skill: addition
# Actual Skill: median
# Prediction Confidence: 0.186
#
# Step 14:
# Predicted Skill: pattern-finding
# Actual Skill: ordering-numbers
# Prediction Confidence: 0.165
#
# Step 15:
# Predicted Skill: pattern-finding
# Actual Skill: mean
# Prediction Confidence: 0.148
#
# Step 16:
# Predicted Skill: pattern-finding
# Actual Skill: median
# Prediction Confidence: 0.243
#
# Step 17:
# Predicted Skill: pattern-finding
# Actual Skill: reading-graph
# Prediction Confidence: 0.248
#
# Step 18:
# Predicted Skill: pattern-finding
# Actual Skill: reading-graph
# Prediction Confidence: 0.121
#
# Step 19:
# Predicted Skill: pattern-finding
# Actual Skill: reading-graph
# Prediction Confidence: 0.039
#
# Step 20:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.080
#
# Step 21:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.160
#
# Step 22:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.314
#
# Step 23:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.477
#
# Step 24:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.507
#
# Step 25:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.582
#
# Step 26:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.648
#
# Step 27:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.695
#
# Step 28:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.662
#
# Step 29:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.676
#
# Step 30:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.699
#
# Step 31:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.719
#
# Step 32:
# Predicted Skill: reading-graph
# Actual Skill: mode
# Prediction Confidence: 0.676
#
# Step 33:
# Predicted Skill: reading-graph
# Actual Skill: median
# Prediction Confidence: 0.557
#
# Step 34:
# Predicted Skill: reading-graph
# Actual Skill: mean
# Prediction Confidence: 0.380
#
# Step 35:
# Predicted Skill: reading-graph
# Actual Skill: mean
# Prediction Confidence: 0.187
#
# Step 36:
# Predicted Skill: reading-graph
# Actual Skill: mean
# Prediction Confidence: 0.076
#
# Step 37:
# Predicted Skill: reading-graph
# Actual Skill: median
# Prediction Confidence: 0.028
#
# Step 38:
# Predicted Skill: addition
# Actual Skill: median
# Prediction Confidence: 0.026
#
# Step 39:
# Predicted Skill: pattern-finding
# Actual Skill: median
# Prediction Confidence: 0.032
#
# Step 40:
# Predicted Skill: pattern-finding
# Actual Skill: median
# Prediction Confidence: 0.040
#
# Step 41:
# Predicted Skill: pattern-finding
# Actual Skill: median
# Prediction Confidence: 0.044
#
# Step 42:
# Predicted Skill: pattern-finding
# Actual Skill: median
# Prediction Confidence: 0.045
#
# Step 43:
# Predicted Skill: pattern-finding
# Actual Skill: mean
# Prediction Confidence: 0.039
#
# Step 44:
# Predicted Skill: pattern-finding
# Actual Skill: mean
# Prediction Confidence: 0.079
#
# Step 45:
# Predicted Skill: pattern-finding
# Actual Skill: mean
# Prediction Confidence: 0.099
#
# Step 46:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.113
#
# Step 47:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.255
#
# Step 48:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.365
#
# Step 49:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.461
#
# Sequence 2 Analysis:
#
# Step 1:
# Predicted Skill: application: multi-column subtraction
# Actual Skill: multiplication
# Prediction Confidence: 0.291
#
# Step 2:
# Predicted Skill: application: multi-column subtraction
# Actual Skill: multiplication
# Prediction Confidence: 0.062
#
# Step 3:
# Predicted Skill: multiplication
# Actual Skill: multiplication
# Prediction Confidence: 0.166
#
# Step 4:
# Predicted Skill: multiplication
# Actual Skill: median
# Prediction Confidence: 0.258
#
# Step 5:
# Predicted Skill: multiplication
# Actual Skill: mean
# Prediction Confidence: 0.189
#
# Step 6:
# Predicted Skill: multiplication
# Actual Skill: mean
# Prediction Confidence: 0.069
#
# Step 7:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.063
#
# Step 8:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.150
#
# Step 9:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.293
#
# Step 10:
# Predicted Skill: addition
# Actual Skill: median
# Prediction Confidence: 0.394
#
# Step 11:
# Predicted Skill: addition
# Actual Skill: median
# Prediction Confidence: 0.320
#
# Step 12:
# Predicted Skill: pattern-finding
# Actual Skill: median
# Prediction Confidence: 0.204
#
# Step 13:
# Predicted Skill: pattern-finding
# Actual Skill: ordering-numbers
# Prediction Confidence: 0.188
#
# Step 14:
# Predicted Skill: pattern-finding
# Actual Skill: mean
# Prediction Confidence: 0.167
#
# Step 15:
# Predicted Skill: pattern-finding
# Actual Skill: median
# Prediction Confidence: 0.265
#
# Step 16:
# Predicted Skill: pattern-finding
# Actual Skill: reading-graph
# Prediction Confidence: 0.266
#
# Step 17:
# Predicted Skill: pattern-finding
# Actual Skill: reading-graph
# Prediction Confidence: 0.129
#
# Step 18:
# Predicted Skill: pattern-finding
# Actual Skill: reading-graph
# Prediction Confidence: 0.041
#
# Step 19:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.082
#
# Step 20:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.162
#
# Step 21:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.316
#
# Step 22:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.479
#
# Step 23:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.509
#
# Step 24:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.583
#
# Step 25:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.649
#
# Step 26:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.695
#
# Step 27:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.662
#
# Step 28:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.676
#
# Step 29:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.699
#
# Step 30:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.719
#
# Step 31:
# Predicted Skill: reading-graph
# Actual Skill: mode
# Prediction Confidence: 0.676
#
# Step 32:
# Predicted Skill: reading-graph
# Actual Skill: median
# Prediction Confidence: 0.557
#
# Step 33:
# Predicted Skill: reading-graph
# Actual Skill: mean
# Prediction Confidence: 0.380
#
# Step 34:
# Predicted Skill: reading-graph
# Actual Skill: mean
# Prediction Confidence: 0.187
#
# Step 35:
# Predicted Skill: reading-graph
# Actual Skill: mean
# Prediction Confidence: 0.076
#
# Step 36:
# Predicted Skill: reading-graph
# Actual Skill: median
# Prediction Confidence: 0.028
#
# Step 37:
# Predicted Skill: addition
# Actual Skill: median
# Prediction Confidence: 0.026
#
# Step 38:
# Predicted Skill: pattern-finding
# Actual Skill: median
# Prediction Confidence: 0.032
#
# Step 39:
# Predicted Skill: pattern-finding
# Actual Skill: median
# Prediction Confidence: 0.040
#
# Step 40:
# Predicted Skill: pattern-finding
# Actual Skill: median
# Prediction Confidence: 0.044
#
# Step 41:
# Predicted Skill: pattern-finding
# Actual Skill: median
# Prediction Confidence: 0.045
#
# Step 42:
# Predicted Skill: pattern-finding
# Actual Skill: mean
# Prediction Confidence: 0.039
#
# Step 43:
# Predicted Skill: pattern-finding
# Actual Skill: mean
# Prediction Confidence: 0.079
#
# Step 44:
# Predicted Skill: pattern-finding
# Actual Skill: mean
# Prediction Confidence: 0.099
#
# Step 45:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.113
#
# Step 46:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.255
#
# Step 47:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.365
#
# Step 48:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.461
#
# Step 49:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.528
#
# Sequence 3 Analysis:
#
# Step 1:
# Predicted Skill: multiplication
# Actual Skill: multiplication
# Prediction Confidence: 0.519
#
# Step 2:
# Predicted Skill: multiplication
# Actual Skill: multiplication
# Prediction Confidence: 0.705
#
# Step 3:
# Predicted Skill: multiplication
# Actual Skill: median
# Prediction Confidence: 0.647
#
# Step 4:
# Predicted Skill: multiplication
# Actual Skill: mean
# Prediction Confidence: 0.438
#
# Step 5:
# Predicted Skill: multiplication
# Actual Skill: mean
# Prediction Confidence: 0.144
#
# Step 6:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.077
#
# Step 7:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.181
#
# Step 8:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.338
#
# Step 9:
# Predicted Skill: addition
# Actual Skill: median
# Prediction Confidence: 0.436
#
# Step 10:
# Predicted Skill: addition
# Actual Skill: median
# Prediction Confidence: 0.351
#
# Step 11:
# Predicted Skill: pattern-finding
# Actual Skill: median
# Prediction Confidence: 0.232
#
# Step 12:
# Predicted Skill: pattern-finding
# Actual Skill: ordering-numbers
# Prediction Confidence: 0.210
#
# Step 13:
# Predicted Skill: pattern-finding
# Actual Skill: mean
# Prediction Confidence: 0.183
#
# Step 14:
# Predicted Skill: pattern-finding
# Actual Skill: median
# Prediction Confidence: 0.282
#
# Step 15:
# Predicted Skill: pattern-finding
# Actual Skill: reading-graph
# Prediction Confidence: 0.280
#
# Step 16:
# Predicted Skill: pattern-finding
# Actual Skill: reading-graph
# Prediction Confidence: 0.135
#
# Step 17:
# Predicted Skill: pattern-finding
# Actual Skill: reading-graph
# Prediction Confidence: 0.042
#
# Step 18:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.084
#
# Step 19:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.164
#
# Step 20:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.319
#
# Step 21:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.481
#
# Step 22:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.510
#
# Step 23:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.584
#
# Step 24:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.649
#
# Step 25:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.696
#
# Step 26:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.662
#
# Step 27:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.676
#
# Step 28:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.699
#
# Step 29:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.719
#
# Step 30:
# Predicted Skill: reading-graph
# Actual Skill: mode
# Prediction Confidence: 0.676
#
# Step 31:
# Predicted Skill: reading-graph
# Actual Skill: median
# Prediction Confidence: 0.557
#
# Step 32:
# Predicted Skill: reading-graph
# Actual Skill: mean
# Prediction Confidence: 0.380
#
# Step 33:
# Predicted Skill: reading-graph
# Actual Skill: mean
# Prediction Confidence: 0.187
#
# Step 34:
# Predicted Skill: reading-graph
# Actual Skill: mean
# Prediction Confidence: 0.076
#
# Step 35:
# Predicted Skill: reading-graph
# Actual Skill: median
# Prediction Confidence: 0.028
#
# Step 36:
# Predicted Skill: addition
# Actual Skill: median
# Prediction Confidence: 0.026
#
# Step 37:
# Predicted Skill: pattern-finding
# Actual Skill: median
# Prediction Confidence: 0.032
#
# Step 38:
# Predicted Skill: pattern-finding
# Actual Skill: median
# Prediction Confidence: 0.040
#
# Step 39:
# Predicted Skill: pattern-finding
# Actual Skill: median
# Prediction Confidence: 0.044
#
# Step 40:
# Predicted Skill: pattern-finding
# Actual Skill: median
# Prediction Confidence: 0.045
#
# Step 41:
# Predicted Skill: pattern-finding
# Actual Skill: mean
# Prediction Confidence: 0.039
#
# Step 42:
# Predicted Skill: pattern-finding
# Actual Skill: mean
# Prediction Confidence: 0.079
#
# Step 43:
# Predicted Skill: pattern-finding
# Actual Skill: mean
# Prediction Confidence: 0.099
#
# Step 44:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.113
#
# Step 45:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.255
#
# Step 46:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.365
#
# Step 47:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.461
#
# Step 48:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.528
#
# Step 49:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.566
#
# Sequence 4 Analysis:
#
# Step 1:
# Predicted Skill: multiplication
# Actual Skill: multiplication
# Prediction Confidence: 0.519
#
# Step 2:
# Predicted Skill: multiplication
# Actual Skill: median
# Prediction Confidence: 0.478
#
# Step 3:
# Predicted Skill: multiplication
# Actual Skill: mean
# Prediction Confidence: 0.277
#
# Step 4:
# Predicted Skill: multiplication
# Actual Skill: mean
# Prediction Confidence: 0.073
#
# Step 5:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.144
#
# Step 6:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.294
#
# Step 7:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.457
#
# Step 8:
# Predicted Skill: addition
# Actual Skill: median
# Prediction Confidence: 0.536
#
# Step 9:
# Predicted Skill: addition
# Actual Skill: median
# Prediction Confidence: 0.427
#
# Step 10:
# Predicted Skill: addition
# Actual Skill: median
# Prediction Confidence: 0.265
#
# Step 11:
# Predicted Skill: pattern-finding
# Actual Skill: ordering-numbers
# Prediction Confidence: 0.225
#
# Step 12:
# Predicted Skill: pattern-finding
# Actual Skill: mean
# Prediction Confidence: 0.191
#
# Step 13:
# Predicted Skill: pattern-finding
# Actual Skill: median
# Prediction Confidence: 0.289
#
# Step 14:
# Predicted Skill: pattern-finding
# Actual Skill: reading-graph
# Prediction Confidence: 0.283
#
# Step 15:
# Predicted Skill: pattern-finding
# Actual Skill: reading-graph
# Prediction Confidence: 0.134
#
# Step 16:
# Predicted Skill: pattern-finding
# Actual Skill: reading-graph
# Prediction Confidence: 0.041
#
# Step 17:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.082
#
# Step 18:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.163
#
# Step 19:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.317
#
# Step 20:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.480
#
# Step 21:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.510
#
# Step 22:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.584
#
# Step 23:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.649
#
# Step 24:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.696
#
# Step 25:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.662
#
# Step 26:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.676
#
# Step 27:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.699
#
# Step 28:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.720
#
# Step 29:
# Predicted Skill: reading-graph
# Actual Skill: mode
# Prediction Confidence: 0.676
#
# Step 30:
# Predicted Skill: reading-graph
# Actual Skill: median
# Prediction Confidence: 0.557
#
# Step 31:
# Predicted Skill: reading-graph
# Actual Skill: mean
# Prediction Confidence: 0.381
#
# Step 32:
# Predicted Skill: reading-graph
# Actual Skill: mean
# Prediction Confidence: 0.187
#
# Step 33:
# Predicted Skill: reading-graph
# Actual Skill: mean
# Prediction Confidence: 0.076
#
# Step 34:
# Predicted Skill: reading-graph
# Actual Skill: median
# Prediction Confidence: 0.028
#
# Step 35:
# Predicted Skill: addition
# Actual Skill: median
# Prediction Confidence: 0.026
#
# Step 36:
# Predicted Skill: pattern-finding
# Actual Skill: median
# Prediction Confidence: 0.032
#
# Step 37:
# Predicted Skill: pattern-finding
# Actual Skill: median
# Prediction Confidence: 0.040
#
# Step 38:
# Predicted Skill: pattern-finding
# Actual Skill: median
# Prediction Confidence: 0.044
#
# Step 39:
# Predicted Skill: pattern-finding
# Actual Skill: median
# Prediction Confidence: 0.045
#
# Step 40:
# Predicted Skill: pattern-finding
# Actual Skill: mean
# Prediction Confidence: 0.039
#
# Step 41:
# Predicted Skill: pattern-finding
# Actual Skill: mean
# Prediction Confidence: 0.079
#
# Step 42:
# Predicted Skill: pattern-finding
# Actual Skill: mean
# Prediction Confidence: 0.099
#
# Step 43:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.113
#
# Step 44:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.255
#
# Step 45:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.365
#
# Step 46:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.461
#
# Step 47:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.528
#
# Step 48:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.566
#
# Step 49:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.585
#
# Sequence 5 Analysis:
#
# Step 1:
# Predicted Skill: multiplication
# Actual Skill: median
# Prediction Confidence: 0.116
#
# Step 2:
# Predicted Skill: multiplication
# Actual Skill: mean
# Prediction Confidence: 0.062
#
# Step 3:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.078
#
# Step 4:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.311
#
# Step 5:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.487
#
# Step 6:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.609
#
# Step 7:
# Predicted Skill: addition
# Actual Skill: median
# Prediction Confidence: 0.652
#
# Step 8:
# Predicted Skill: addition
# Actual Skill: median
# Prediction Confidence: 0.522
#
# Step 9:
# Predicted Skill: addition
# Actual Skill: median
# Prediction Confidence: 0.328
#
# Step 10:
# Predicted Skill: pattern-finding
# Actual Skill: ordering-numbers
# Prediction Confidence: 0.251
#
# Step 11:
# Predicted Skill: pattern-finding
# Actual Skill: mean
# Prediction Confidence: 0.206
#
# Step 12:
# Predicted Skill: pattern-finding
# Actual Skill: median
# Prediction Confidence: 0.302
#
# Step 13:
# Predicted Skill: pattern-finding
# Actual Skill: reading-graph
# Prediction Confidence: 0.289
#
# Step 14:
# Predicted Skill: pattern-finding
# Actual Skill: reading-graph
# Prediction Confidence: 0.134
#
# Step 15:
# Predicted Skill: pattern-finding
# Actual Skill: reading-graph
# Prediction Confidence: 0.040
#
# Step 16:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.080
#
# Step 17:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.160
#
# Step 18:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.315
#
# Step 19:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.479
#
# Step 20:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.509
#
# Step 21:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.583
#
# Step 22:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.649
#
# Step 23:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.696
#
# Step 24:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.662
#
# Step 25:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.677
#
# Step 26:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.699
#
# Step 27:
# Predicted Skill: reading-graph
# Actual Skill: reading-graph
# Prediction Confidence: 0.720
#
# Step 28:
# Predicted Skill: reading-graph
# Actual Skill: mode
# Prediction Confidence: 0.676
#
# Step 29:
# Predicted Skill: reading-graph
# Actual Skill: median
# Prediction Confidence: 0.557
#
# Step 30:
# Predicted Skill: reading-graph
# Actual Skill: mean
# Prediction Confidence: 0.381
#
# Step 31:
# Predicted Skill: reading-graph
# Actual Skill: mean
# Prediction Confidence: 0.187
#
# Step 32:
# Predicted Skill: reading-graph
# Actual Skill: mean
# Prediction Confidence: 0.076
#
# Step 33:
# Predicted Skill: reading-graph
# Actual Skill: median
# Prediction Confidence: 0.028
#
# Step 34:
# Predicted Skill: addition
# Actual Skill: median
# Prediction Confidence: 0.026
#
# Step 35:
# Predicted Skill: pattern-finding
# Actual Skill: median
# Prediction Confidence: 0.032
#
# Step 36:
# Predicted Skill: pattern-finding
# Actual Skill: median
# Prediction Confidence: 0.040
#
# Step 37:
# Predicted Skill: pattern-finding
# Actual Skill: median
# Prediction Confidence: 0.044
#
# Step 38:
# Predicted Skill: pattern-finding
# Actual Skill: median
# Prediction Confidence: 0.045
#
# Step 39:
# Predicted Skill: pattern-finding
# Actual Skill: mean
# Prediction Confidence: 0.039
#
# Step 40:
# Predicted Skill: pattern-finding
# Actual Skill: mean
# Prediction Confidence: 0.079
#
# Step 41:
# Predicted Skill: pattern-finding
# Actual Skill: mean
# Prediction Confidence: 0.099
#
# Step 42:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.113
#
# Step 43:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.255
#
# Step 44:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.365
#
# Step 45:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.461
#
# Step 46:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.528
#
# Step 47:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.566
#
# Step 48:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.585
#
# Step 49:
# Predicted Skill: addition
# Actual Skill: mean
# Prediction Confidence: 0.591
